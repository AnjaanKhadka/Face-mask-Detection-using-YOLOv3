# %% [markdown]
# # Getting Things Ready

# %% [markdown]
# To mount google drive to colab

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Unzipping dataset file

# %%
# !unzip "/content/drive/MyDrive/dataset.zip" -d "/content/drive/MyDrive/dataset"

# %% [markdown]
# Cloning darknet repository

# %%
# %cd /content/drive/MyDrive/darknet

# %%
# !git clone https://github.com/AlexeyAB/darknet.git

# %% [markdown]
# Changing MakeFile and executing it

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %%
# Execute this to change more in makefile.
# This allows you to use YOLO API.
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile

# %%
# !make

# %% [markdown]
# To change the cfg file

# %%
# Change classes=2 depending upon no f classes you have 
# Change filters=21 to filters=n where n should be calculated as n = (no_of_classes+5)*3
# If you want to change max batches then change steps to values of around 80% and 90% respectively
# !sed -i 's/batch=1/batch=16/' cfg/yolov3.cfg
# !sed -i 's/subdivisions=1/subdivisions=8/' cfg/yolov3.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3.cfg
# !sed -i 's/steps=400000,450000/steps=3200,3600/' cfg/yolov3.cfg
# !sed -i '610 s@classes=80@classes=2@' cfg/yolov3.cfg
# !sed -i '696 s@classes=80@classes=2@' cfg/yolov3.cfg
# !sed -i '783 s@classes=80@classes=2@' cfg/yolov3.cfg
# !sed -i '603 s@filters=255@filters=21@' cfg/yolov3.cfg
# !sed -i '689 s@filters=255@filters=21@' cfg/yolov3.cfg
# !sed -i '776 s@filters=255@filters=21@' cfg/yolov3.cfg

# %% [markdown]
# Downloading pretrained weights for transfer learning

# %%
# %cd /content/drive/MyDrive
# !mkdir pretrained_model
# !mkdir backup
# %cd /content/drive/MyDrive/pretrained_model
# !wget https://pjreddie.com/media/files/darknet53.conv.74

# %% [markdown]
# Execute create_test.py to create train.txt and test.txt files.
#
# For this upload create_test.py to same directory as dataset, and execute following command.

# %%
# !python /content/drive/MyDrive/dataset/create_test.py

# %% [markdown]
# create obj.data

# %%
# !echo -e "Mask\nNo-Mask" > dataset/obj.names
# !echo -e 'classes= 1\ntrain  = dataset/train.txt\nvalid  = dataset/test.txt\nnames = dataset/obj.names\nbackup = /mydrive/yolov3' > dataset/obj.data
# !mkdir data/obj

# %% [markdown]
# # Start Training

# %%
dat = '/content/drive/MyDrive/dataset/obj.data'
cfg = '/content/drive/MyDrive/darknet/cfg/yolov3.cfg'
wgt = '/content/drive/MyDrive/pretrained_model/darknet53.conv.74'
# !darknet/darknet detector train {dat} {cfg} {wgt} -dont_show -map

# %%
# Execute this code if darknet permission denied occurs.
# !chmod +x darknet/darknet
